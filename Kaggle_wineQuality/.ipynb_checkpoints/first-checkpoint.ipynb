# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import preprocessing, metrics, model_selection, tree, ensemble

# %%
df = pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
## columns
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1596 entries, 0 to 1595
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1596 non-null   float64
#  1   volatile acidity      1596 non-null   float64
#  2   citric acid           1596 non-null   float64
#  3   residual sugar        1596 non-null   float64
#  4   chlorides             1596 non-null   float64
#  5   free sulfur dioxide   1596 non-null   float64
#  6   total sulfur dioxide  1596 non-null   float64
#  7   density               1596 non-null   float64
#  8   pH                    1596 non-null   float64
#  9   sulphates             1596 non-null   float64
#  10  alcohol               1596 non-null   float64
#  11  quality               1596 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 149.8 KB

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1596.0   8.314160   1.732203  4.60000   7.1000
# volatile acidity      1596.0   0.527954   0.179176  0.12000   0.3900
# citric acid           1596.0   0.270276   0.193894  0.00000   0.0900
# residual sugar        1596.0   2.535558   1.405515  0.90000   1.9000
# chlorides             1596.0   0.087120   0.045251  0.01200   0.0700
# free sulfur dioxide   1596.0  15.858396  10.460554  1.00000   7.0000
# total sulfur dioxide  1596.0  46.382206  32.839138  6.00000  22.0000
# density               1596.0   0.996744   0.001888  0.99007   0.9956
# pH                    1596.0   3.311917   0.153346  2.86000   3.2100
# sulphates             1596.0   0.656385   0.163057  0.33000   0.5500
# alcohol               1596.0  10.421147   1.060371  8.40000   9.5000
# quality               1596.0   5.637218   0.807080  3.00000   5.0000
#
#                             50%        75%        max
# ...

# %%
## Dependent Dataset

df.quality.value_counts()
# Out:
# 5    680
# 6    637
# 7    199
# 4     52
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# #### Only 5 different values are shown for the quality of the winesamples

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df.drop(['fixed acidity', 'density', 'free sulfur dioxide', 'pH', 'citric acid'],axis=1,inplace=True)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### EDA Starts

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1596 entries, 0 to 1595
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   volatile acidity      1596 non-null   float64
#  1   residual sugar        1596 non-null   float64
#  2   chlorides             1596 non-null   float64
#  3   total sulfur dioxide  1596 non-null   float64
#  4   sulphates             1596 non-null   float64
#  5   alcohol               1596 non-null   float64
#  6   quality               1596 non-null   int64
# dtypes: float64(6), int64(1)
# memory usage: 87.4 KB

# %%
df.hist(figsize=(15,15))
plt.show()
